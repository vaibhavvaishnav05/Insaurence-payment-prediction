# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("insurance (1).csv")

# %%
df
# Out:
#         Id   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0        1  39.0    male  23.2             91      Yes         0     No
# 1        2  24.0    male  30.1             87       No         0     No
# 2        3   NaN    male  33.3             82      Yes         0     No
# 3        4   NaN    male  33.7             80       No         0     No
# 4        5   NaN    male  34.1            100       No         0     No
# ...    ...   ...     ...   ...            ...      ...       ...    ...
# 1335  1336  44.0  female  35.5             88      Yes         0    Yes
# 1336  1337  59.0  female  38.1            120       No         1    Yes
# 1337  1338  30.0    male  34.5             91      Yes         3    Yes
# 1338  1339  37.0    male  30.4            106       No         0    Yes
# 1339  1340  30.0  female  47.4            101       No         0    Yes
#
#          region     claim
# 0     southeast   1121.87
# 1     southeast   1131.51
# 2     southeast   1135.94
# 3     northwest   1136.40
# 4     northwest   1137.01
# ...         ...       ...
# 1335  northwest  55135.40
# 1336  northeast  58571.07
# 1337  northwest  60021.40
# 1338  southeast  62592.87
# 1339  southeast  63770.43
#
# [1340 rows x 10 columns]

# %%
df.head(10)
# Out:
#    Id   age gender   bmi  bloodpressure diabetic  children smoker     region  \
# 0   1  39.0   male  23.2             91      Yes         0     No  southeast
# 1   2  24.0   male  30.1             87       No         0     No  southeast
# 2   3   NaN   male  33.3             82      Yes         0     No  southeast
# 3   4   NaN   male  33.7             80       No         0     No  northwest
# 4   5   NaN   male  34.1            100       No         0     No  northwest
# 5   6   NaN   male  34.4             96      Yes         0     No  northwest
# 6   7   NaN   male  37.3             86      Yes         0     No  northwest
# 7   8  19.0   male  41.1            100       No         0     No  northwest
# 8   9  20.0   male  43.0             86       No         0     No  northwest
# 9  10  30.0   male  53.1             97       No         0     No  northwest
#
#      claim
# 0  1121.87
# 1  1131.51
# 2  1135.94
# 3  1136.40
# 4  1137.01
# 5  1137.47
# 6  1141.45
# 7  1146.80
# 8  1149.40
# 9  1163.46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1340 non-null   int64
#  1   age            1335 non-null   float64
#  2   gender         1340 non-null   object
#  3   bmi            1340 non-null   float64
#  4   bloodpressure  1340 non-null   int64
#  5   diabetic       1340 non-null   object
#  6   children       1340 non-null   int64
#  7   smoker         1340 non-null   object
#  8   region         1337 non-null   object
#  9   claim          1340 non-null   float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 104.8+ KB

# %%
df.shape
# Out:
# (1340, 10)

# %%
df.columns
# Out:
# Index(['Id', 'age', 'gender', 'bmi', 'bloodpressure', 'diabetic', 'children',
#        'smoker', 'region', 'claim'],
#       dtype='object')

# %%
pd.set_option("display.float_format","{:.2f}".format)

# %%
df
# Out:
#         Id   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0        1 39.00    male 23.20             91      Yes         0     No
# 1        2 24.00    male 30.10             87       No         0     No
# 2        3   NaN    male 33.30             82      Yes         0     No
# 3        4   NaN    male 33.70             80       No         0     No
# 4        5   NaN    male 34.10            100       No         0     No
# ...    ...   ...     ...   ...            ...      ...       ...    ...
# 1335  1336 44.00  female 35.50             88      Yes         0    Yes
# 1336  1337 59.00  female 38.10            120       No         1    Yes
# 1337  1338 30.00    male 34.50             91      Yes         3    Yes
# 1338  1339 37.00    male 30.40            106       No         0    Yes
# 1339  1340 30.00  female 47.40            101       No         0    Yes
#
#          region    claim
# 0     southeast  1121.87
# 1     southeast  1131.51
# 2     southeast  1135.94
# 3     northwest  1136.40
# 4     northwest  1137.01
# ...         ...      ...
# 1335  northwest 55135.40
# 1336  northeast 58571.07
# 1337  northwest 60021.40
# 1338  southeast 62592.87
# 1339  southeast 63770.43
#
# [1340 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# Id               0
# age              5
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           3
# claim            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1332, 10)

# %%
df.describe()
# Out:
#            Id     age     bmi  bloodpressure  children    claim
# count 1332.00 1332.00 1332.00        1332.00   1332.00  1332.00
# mean   674.47   38.09   30.66          94.19      1.10 13325.25
# std    384.70   11.11    6.12          11.45      1.21 12109.62
# min      1.00   18.00   16.00          80.00      0.00  1121.87
# 25%    341.75   29.00   26.20          86.00      0.00  4760.16
# 50%    674.50   38.00   30.35          92.00      1.00  9412.97
# 75%   1007.25   47.00   34.73          99.00      2.00 16781.33
# max   1340.00   60.00   53.10         140.00      5.00 63770.43

# %%
numeric_cols=['age',  'bmi', 'bloodpressure', 'children', 'claim']
df[numeric_cols].hist(bins=20,figsize=(20,8),color="skyblue",edgecolor="black")
plt.suptitle("insaurence power",fontsize=16)
plt.show()

# %%
cat_cols=['gender', 'diabetic', 'smoker', 'region']
plt.figure(figsize=(20,6))
for i,col in enumerate(cat_cols,1):
    plt.subplot(2,2,i)
    sns.countplot(data=df,  x=col)
    plt.title(f"insaurence power {col}")
plt.tight_layout()
plt.show()

# %%
df.groupby(["gender","smoker"])["claim"].mean().round(2)
# Out:
# gender  smoker
# female  No        8762.30
#         Yes      30679.00
# male    No        8169.25
#         Yes      33042.01
# Name: claim, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df,x="gender",y="claim",hue="smoker",estimator="mean",errorbar="sd")
plt.title("Avarage insaurence claim by gender & smoking status")
plt.show()

# %%
pivot_region_diabetic= df.groupby(["region","diabetic"])["claim"].mean().unstack()

# %%
pivot_region_diabetic
# Out:
# diabetic        No      Yes
# region
# northeast 16966.86 16818.30
# northwest 11442.83 12224.96
# southeast 13578.72 12574.09
# southwest 13069.91 12313.74

# %%
pivot_region_diabetic.plot(kind="bar",figsize=(8,5))
plt.title("average claim by region & diabetic status")
plt.ylabel("mean claim")
plt.show()

# %%
pivot_table=pd.pivot_table(df,values="claim",index="region",columns="smoker",aggfunc="mean")
pivot_table
# Out:
# smoker          No      Yes
# region
# northeast 11666.11 29673.54
# northwest  8076.20 30192.00
# southeast  7444.14 34845.00
# southwest  8294.75 32269.06

# %%
pivot_table=pd.pivot_table(df,values="claim",index="children",columns="diabetic",aggfunc="mean")
pivot_table
# Out:
# diabetic       No      Yes
# children
# 0        12967.40 11985.29
# 1        12730.46 12732.06
# 2        15567.77 14579.36
# 3        13807.61 17091.26
# 4        14106.63 13573.35
# 5         8519.04  9205.59

# %%
numeric_cols
# Out:
# ['age', 'bmi', 'bloodpressure', 'children', 'claim']

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.scatterplot(data=df,x="age",y="claim",hue="smoker",style="gender")
plt.title("Claim vs age by smoker & gender")
plt.show()

# %%
sns.regplot(data=df,x="bmi",y="claim",scatter_kws={"alpha":0.6})
plt.title("Relatioship Between Bmi and claim Amount ")
plt.show()

# %%
sns.boxplot(data=df,x="children",y="claim")
plt.title("Claim distribution by number of children")
plt.show()

# %%
df["age_group"]=pd.cut(df["age"],bins=[0,18,30,45,60,100],labels=["<18","18-30","31-45","46-60","60+"])
df
# Out:
#         Id   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0        1 39.00    male 23.20             91      Yes         0     No
# 1        2 24.00    male 30.10             87       No         0     No
# 7        8 19.00    male 41.10            100       No         0     No
# 8        9 20.00    male 43.00             86       No         0     No
# 9       10 30.00    male 53.10             97       No         0     No
# ...    ...   ...     ...   ...            ...      ...       ...    ...
# 1335  1336 44.00  female 35.50             88      Yes         0    Yes
# 1336  1337 59.00  female 38.10            120       No         1    Yes
# 1337  1338 30.00    male 34.50             91      Yes         3    Yes
# 1338  1339 37.00    male 30.40            106       No         0    Yes
# 1339  1340 30.00  female 47.40            101       No         0    Yes
#
#          region    claim age_group
# 0     southeast  1121.87     31-45
# 1     southeast  1131.51     18-30
# 7     northwest  1146.80     18-30
# 8     northwest  1149.40     18-30
# 9     northwest  1163.46     18-30
# ...         ...      ...       ...
# 1335  northwest 55135.40     31-45
# 1336  northeast 58571.07     46-60
# 1337  northwest 60021.40     18-30
# 1338  southeast 62592.87     31-45
# 1339  southeast 63770.43     18-30
#
# [1332 rows x 11 columns]

# %%
df["age_group"].value_counts()
# Out:
# age_group
# 31-45    553
# 46-60    383
# 18-30    380
# <18       16
# 60+        0
# Name: count, dtype: int64

# %%
sns.barplot(data=df,x="age_group",y="claim",estimator="mean",errorbar= "sd")
plt.title("Average claim by aget")
plt.show()

# %%
df["bmi_category"]=pd.cut(df["bmi"],bins=[0,18.5,24.9,29.9,100],labels=["under weight","Normal","overweight","obese"])
df
# Out:
#         Id   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0        1 39.00    male 23.20             91      Yes         0     No
# 1        2 24.00    male 30.10             87       No         0     No
# 7        8 19.00    male 41.10            100       No         0     No
# 8        9 20.00    male 43.00             86       No         0     No
# 9       10 30.00    male 53.10             97       No         0     No
# ...    ...   ...     ...   ...            ...      ...       ...    ...
# 1335  1336 44.00  female 35.50             88      Yes         0    Yes
# 1336  1337 59.00  female 38.10            120       No         1    Yes
# 1337  1338 30.00    male 34.50             91      Yes         3    Yes
# 1338  1339 37.00    male 30.40            106       No         0    Yes
# 1339  1340 30.00  female 47.40            101       No         0    Yes
#
#          region    claim age_group bmi_category
# 0     southeast  1121.87     31-45       Normal
# 1     southeast  1131.51     18-30        obese
# 7     northwest  1146.80     18-30        obese
# 8     northwest  1149.40     18-30        obese
# 9     northwest  1163.46     18-30        obese
# ...         ...      ...       ...          ...
# 1335  northwest 55135.40     31-45        obese
# 1336  northeast 58571.07     46-60        obese
# 1337  northwest 60021.40     18-30        obese
# 1338  southeast 62592.87     31-45        obese
# 1339  southeast 63770.43     18-30        obese
#
# [1332 rows x 12 columns]

# %%
df["bmi_category"].value_counts()
# Out:
# bmi_category
# obese           702
# overweight      387
# Normal          222
# under weight     21
# Name: count, dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.boxplot(data=df,x="bmi_category",y="claim")
plt.title("Claim distribution by bmi category")
plt.show()

# %%
region_stats=df.groupby("region").agg(
    smoker_rate=("smoker",lambda x:(x=="Yes").mean()*100),
    mean_claim=("claim","mean")
).reset_index()

# %%
region_stats
# Out:
#       region  smoker_rate  mean_claim
# 0  northeast        29.00    16889.04
# 1  northwest        16.81    11794.22
# 2  southeast        20.59    13085.50
# 3  southwest        18.47    12723.13

# %%
fig,ax1=plt.subplots(figsize=(8,5))
sns.barplot(data=region_stats,x="region",y="smoker_rate",ax=ax1,alpha=0.6)
ax2=ax1.twinx()
sns.lineplot(data=region_stats,x="region",y="mean_claim",ax=ax2,color="red",marker="o")
ax1.set_ylabel("Smoker Rate (%)")
ax2.set_ylabel("Average Claim($)")
plt.title("Smoker Rate and Average Claim by region")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
import joblib

# %%
df.columns
# Out:
# Index(['Id', 'age', 'gender', 'bmi', 'bloodpressure', 'diabetic', 'children',
#        'smoker', 'region', 'claim', 'age_group', 'bmi_category'],
#       dtype='object')

# %%
X=df[["age", "gender", "bmi", "bloodpressure", "diabetic", "children","smoker"]]
y=df[["claim"]]
X
# Out:
#        age  gender   bmi  bloodpressure diabetic  children smoker
# 0    39.00    male 23.20             91      Yes         0     No
# 1    24.00    male 30.10             87       No         0     No
# 7    19.00    male 41.10            100       No         0     No
# 8    20.00    male 43.00             86       No         0     No
# 9    30.00    male 53.10             97       No         0     No
# ...    ...     ...   ...            ...      ...       ...    ...
# 1335 44.00  female 35.50             88      Yes         0    Yes
# 1336 59.00  female 38.10            120       No         1    Yes
# 1337 30.00    male 34.50             91      Yes         3    Yes
# 1338 37.00    male 30.40            106       No         0    Yes
# 1339 30.00  female 47.40            101       No         0    Yes
#
# [1332 rows x 7 columns]

# %%
cat_cols = ["gender", "diabetic", "smoker"]
label_encoders = {}    # <-- must match everywhere

for col in cat_cols:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])
    label_encoders[col] = le   # <-- use same variable name
    joblib.dump(le, f"label_encoder_{col}.pkl")

# %%
X
# Out:
#        age  gender   bmi  bloodpressure  diabetic  children  smoker
# 0    39.00       1 23.20             91         1         0       0
# 1    24.00       1 30.10             87         0         0       0
# 7    19.00       1 41.10            100         0         0       0
# 8    20.00       1 43.00             86         0         0       0
# 9    30.00       1 53.10             97         0         0       0
# ...    ...     ...   ...            ...       ...       ...     ...
# 1335 44.00       0 35.50             88         1         0       1
# 1336 59.00       0 38.10            120         0         1       1
# 1337 30.00       1 34.50             91         1         3       1
# 1338 37.00       1 30.40            106         0         0       1
# 1339 30.00       0 47.40            101         0         0       1
#
# [1332 rows x 7 columns]

# %%
label_encoders
# Out:
# {'gender': LabelEncoder(),
#  'diabetic': LabelEncoder(),
#  'smoker': LabelEncoder()}

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
num_cols=["age","bmi","bloodpressure","children"]
scaler=StandardScaler()

# %%
X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_test[num_cols] = scaler.transform(X_test[num_cols])

# %%
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
print(X_train.shape,y_train.shape)
# Out:
# (1065, 7) (1065, 1)

# %%
print(X_test.shape,y_test.shape)
# Out:
# (267, 7) (267, 1)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV,cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from xgboost import XGBRegressor

# %%
def evaluate_model(model,X_train,X_test,y_train,y_test):
    y_pred=model.predict(X_test)
    r2=r2_score(y_test,y_pred)
    mae=mean_absolute_error(y_test,y_pred)
    rmse=np.sqrt(mean_squared_error(y_test,y_test))
    return {"R2":r2,"MAE":mae,"RMSE":rmse}

# %%
results={}

# %%
# -----------------------------------------
# Linear Regression
# -----------------------------------------
lr = LinearRegression()
lr.fit(X_train, y_train)
results["Linear Regression"] = evaluate_model(lr, X_train, X_test, y_train, y_test)
print("Linear Regression model trained")

# -----------------------------------------
# Polynomial Regression
# -----------------------------------------
best_poly_score = -np.inf
best_poly_model = None

for degree in [2, 3]:
    poly = PolynomialFeatures(degree=degree)
    X_train_poly = poly.fit_transform(X_train)
    X_test_poly = poly.transform(X_test)

    poly_lr = LinearRegression()
    poly_lr.fit(X_train_poly, y_train)

    score = poly_lr.score(X_test_poly, y_test)

    if score > best_poly_score:
        best_poly_score = score
        best_poly_model = (degree, poly, poly_lr)

degree, poly, poly_lr = best_poly_model

results[f"Polynomial Regression (deg={degree})"] = evaluate_model(
    poly_lr,
    poly.fit_transform(X_train),
    poly.transform(X_test),
    y_train,
    y_test
)

print("Polynomial Regression model trained")

# -----------------------------------------
# Random Forest Regressor
# -----------------------------------------
rf = RandomForestRegressor()

rf_params = {
    "n_estimators": [100, 200],
    "max_depth": [None, 10, 20],
    "min_samples_split": [2, 5],   # FIXED typo: min_sample_split → min_samples_split
    "min_samples_leaf": [1, 2]     # FIXED typo: min_sample_leaf → min_samples_leaf
}

rf_grid = GridSearchCV(rf, rf_params, cv=3, scoring="r2", n_jobs=-1, verbose=0)
rf_grid.fit(X_train, y_train)

best_rf = rf_grid.best_estimator_

results["Random Forest"] = evaluate_model(best_rf, X_train, X_test, y_train, y_test)

print("Random Forest training completed. Best parameters:", rf_grid.best_params_)

# -----------------------------------------
# Support Vector Regressor
# -----------------------------------------
svr = SVR()

svr_params = {
    "kernel": ["rbf", "poly", "linear"],   # FIXED typos: kernal→kernel, rbl→rbf
    "C": [1, 10, 50],
    "epsilon": [0.1, 0.2, 0.5],            # FIXED typo: episilon → epsilon
    "degree": [2, 3]
}

svr_grid = GridSearchCV(svr, svr_params, cv=3, scoring="r2", n_jobs=-1, verbose=0)
svr_grid.fit(X_train, y_train)

best_svr = svr_grid.best_estimator_

results["SVR"] = evaluate_model(best_svr, X_train, X_test, y_train, y_test)

print("SVR Training completed. Best parameters:", svr_grid.best_params_)

# -----------------------------------------
# XGBoost Regressor
# -----------------------------------------
xgb = XGBRegressor(objective="reg:squarederror")

xgb_params = {
    "n_estimators": [100, 200],
    "max_depth": [3, 5, 7],
    "learning_rate": [0.01, 0.05, 0.1],
    "subsample": [0.8, 1.0]
}

xgb_grid = GridSearchCV(xgb, xgb_params, cv=3, scoring="r2", n_jobs=-1, verbose=0)  # FIXED typo: verbous→verbose
xgb_grid.fit(X_train, y_train)

best_xgb = xgb_grid.best_estimator_

results["XGBoost"] = evaluate_model(best_xgb, X_train, X_test, y_train, y_test)     # FIXED wrong parentheses

print("XGBoost training completed. Best parameters:", xgb_grid.best_params_)
# Out:
# Linear Regression model trained
# Polynomial Regression model trained
# Random Forest training completed. Best parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# SVR Training completed. Best parameters: {'C': 50, 'degree': 2, 'epsilon': 0.5, 'kernel': 'linear'}
# XGBoost training completed. Best parameters: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}

# %%
results
# Out:
# {'Linear Regression': {'R2': 0.6885832230157446,
#   'MAE': np.float64(4993.089349402202),
#   'RMSE': np.float64(0.0)},
#  'Polynomial Regression (deg=2)': {'R2': 0.74100723513736,
#   'MAE': np.float64(4438.166985596845),
#   'RMSE': np.float64(0.0)},
#  'Random Forest': {'R2': 0.7812504688076836,
#   'MAE': np.float64(4100.5167066039),
#   'RMSE': np.float64(0.0)},
#  'SVR': {'R2': 0.4926769140410421,
#   'MAE': np.float64(5952.812237080035),
#   'RMSE': np.float64(0.0)},
#  'XGBoost': {'R2': 0.7768394947052002,
#   'MAE': np.float64(4185.3060979195925),
#   'RMSE': np.float64(0.0)}}

# %%
results_df=pd.DataFrame(results).T.sort_values(by="R2",ascending=False)
results_df
# Out:
#                                 R2     MAE  RMSE
# Random Forest                 0.78 4100.52  0.00
# XGBoost                       0.78 4185.31  0.00
# Polynomial Regression (deg=2) 0.74 4438.17  0.00
# Linear Regression             0.69 4993.09  0.00
# SVR                           0.49 5952.81  0.00

# %%
models={
    "Linear Regression":lr,
    "Polynomial Regression":poly_lr,
    "Random Forest":best_rf,
    "SVR":best_svr,
    "XGBoost":best_xgb
}

# %%
best_r2=results_df["R2"].max()

# %%
best_r2
# Out:
# np.float64(0.7812504688076836)

# %%
top_model=results_df[results_df["R2"]==best_r2]

# %%
top_model
# Out:
#                 R2     MAE  RMSE
# Random Forest 0.78 4100.52  0.00

# %%
best_model=models[top_model.index[0]]
best_model
# Out:
# RandomForestRegressor(max_depth=10, min_samples_leaf=2, n_estimators=200)

# %%
joblib.dump(best_model,"best_model.pkl")
print(f"Best model selection :{top_model.index[0]}")
# Out:
# Best model selection :Random Forest
